# %% [markdown]
# <a href="https://colab.research.google.com/github/priscilazayane/Atividades_IBC_Tecnico_IA/blob/main/primeiro_codigo_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**CETAM - IBC** - Técnico em Inteligência Artificial
#
# Manaus, 17 de Março de 2026
#
# **Aluna**: Priscila Zayane / **Turno**: Matutino

# %%
import time
print(time.ctime())
# Out:
# Tue Mar 17 13:05:20 2026

# %%
s = 1
time.sleep(s)
print(time.ctime())
# Out:
# Tue Mar 17 13:12:29 2026

# %%
print('Olá, mundo!!!')
# Out:
# ~Olá, mundo!!!~

# %% [markdown]
# O texto pode ficar em **negrito**
#
# O texto pode ficar em *itálico*
#
# O texto pode ficar ~riscado~

# %% [markdown]
# $\sqrt{3x+1}+(1+x)^2$

# %% [markdown]
# $e^x\sum_{i=0}^\infty \frac{1}{i!}xî$

# %%
print(f"10+5={10+5}") #Soma
print(f"10-5={10-5}") #Subtração
print(f"10*5={10*5}") #Multiplicação
print(f"50/2={50/2}") #Divisão
print(f"10//3={10//3}") #Divisão inteira
print(f"10%3={10%3}") #Módulo
print(f"2**3={2**3}") #Potenciação
print(f"10**0.5={10**0.5}") #Raiz quadrada
# Out:
# 10+5=15
# 10-5=5
# 10*5=50
# 50/2=25.0
# 10//3=3
# 10%3=1
# 2**3=8
# 10**0.5=3.1622776601683795
