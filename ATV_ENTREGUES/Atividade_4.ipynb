# %% [markdown]
# <a href="https://colab.research.google.com/github/priscilazayane/Atividades_IBC_Tecnico_IA/blob/main/Atividade_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **CETAM - IBC** - Curso Técnico de Nível Médio em Inteligência Artificial
#
#
# Manaus, 24 de Março de 2026
#
# **Aluna**: Priscila Zayane / Turno: Matutino

# %%
print("Curso Técnico em Nível Médio de Inteligência Artificial - turma 2026.1")
# Out:
# Curso Técnico em Nível Médio de Inteligência Artificial - turma 2026.1

# %%
nu1 = 10 # Inicializa nu1 com o valor inteiro 0
nu2 = 20 # Inicializa nu2 com o valor inteiro 0
print('Olá, mundo!')

print(5 + 5 - 2)
print(nu1)
print(5 ** 2)
print(nu2)
# Out:
# Olá, mundo!
# 8
# 10
# 25
# 20

# %%
#Script 1
# função criada pelo usuário
def dobro(x):
    print(x * 2)

dobro(125)
# Out:
# 250

# %%
x = 1
if x == 1:
    # recuo de 4 espaços em branco
    print("x é 1.")
y = 33
# Out:
# x é 1.
